# %%
import pandas as pd
import Data_Set 
import matplotlib

# %%
ds = pd.read_csv('Data_Set/Heart_disease_cleveland_new.csv')

# %%
ds
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   0       145   233    1        2      150      0      2.3
# 1     67    1   3       160   286    0        2      108      1      1.5
# 2     67    1   3       120   229    0        2      129      1      2.6
# 3     37    1   2       130   250    0        0      187      0      3.5
# 4     41    0   1       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   0       110   264    0        0      132      0      1.2
# 299   68    1   3       144   193    1        0      141      0      3.4
# 300   57    1   3       130   131    0        0      115      1      1.2
# 301   57    0   1       130   236    0        2      174      0      0.0
# 302   38    1   2       138   175    0        0      173      0      0.0
#
#      slope  ca  thal  target
# 0        2   0     2       0
# 1        1   3     1       1
# ...

# %%
ds['age']
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: age, Length: 303, dtype: int64

# %%
ds['age'].mean()
# Out:
# np.float64(54.43894389438944)

# %%
ds['age'] == 54
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Name: age, Length: 303, dtype: bool

# %%
# ds.loc[ds['age'] == 54, 'age'] #This line shows the age of patients who are 54 years old.
ds_54 = ds.loc[ds['age'] == 54, :] # This line shows all the details of patients who are 54 years old.

# %%
ds_54
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 17    54    1   3       140   239    0        0      160      0      1.2
# 55    54    1   3       124   266    0        2      109      1      2.2
# 58    54    1   2       125   273    0        2      152      0      0.5
# 63    54    0   2       135   304    1        0      170      0      0.0
# 64    54    1   3       120   188    0        0      113      0      1.4
# 67    54    1   2       150   232    0        2      165      0      1.6
# 105   54    1   1       108   309    0        0      156      0      0.0
# 127   54    1   3       110   239    0        0      126      1      2.8
# 130   54    1   2       120   258    0        2      147      0      0.4
# 162   54    0   2       110   214    0        0      158      0      1.6
# 167   54    0   1       132   288    1        2      159      1      0.0
# 188   54    1   1       192   283    0        2      195      0      0.0
# ...

# %%
sort_ds_54_by_sex = ds_54.sort_values('sex', ascending=False) # This line sorts the patients who are 54 years old by their sex in descending order.
sort_ds_54_by_sex
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 17    54    1   3       140   239    0        0      160      0      1.2
# 55    54    1   3       124   266    0        2      109      1      2.2
# 58    54    1   2       125   273    0        2      152      0      0.5
# 64    54    1   3       120   188    0        0      113      0      1.4
# 105   54    1   1       108   309    0        0      156      0      0.0
# 67    54    1   2       150   232    0        2      165      0      1.6
# 127   54    1   3       110   239    0        0      126      1      2.8
# 130   54    1   2       120   258    0        2      147      0      0.4
# 235   54    1   3       122   286    0        2      116      1      3.2
# 188   54    1   1       192   283    0        2      195      0      0.0
# 228   54    1   3       110   206    0        2      108      1      0.0
# 63    54    0   2       135   304    1        0      170      0      0.0
# ...

# %%
sort_ds_54_by_sex.iloc[0:5] # This line shows the first 5 rows of the sorted DataFrame.
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 17    54    1   3       140   239    0        0      160      0      1.2
# 55    54    1   3       124   266    0        2      109      1      2.2
# 58    54    1   2       125   273    0        2      152      0      0.5
# 64    54    1   3       120   188    0        0      113      0      1.4
# 105   54    1   1       108   309    0        0      156      0      0.0
#
#      slope  ca  thal  target
# 17       0   0     1       0
# 55       1   1     3       1
# 58       2   1     1       0
# 64       1   1     3       1
# 105      0   0     3       0

# %%
def popular(s):
    return s.iloc[0]

ds.sort_values('age', ascending=False).groupby([ 'age','sex', 'cp']).agg(popular) #
# Out:
#             trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# age sex cp
# 29  1   1        130   204    0        2      202      0      0.0      0   0
# 34  0   1        118   210    0        0      192      0      0.7      0   0
#     1   0        118   182    0        2      174      0      0.0      0   0
# 35  0   3        138   183    0        0      182      0      1.4      0   0
#     1   1        122   192    0        0      174      0      0.0      0   0
# ...              ...   ...  ...      ...      ...    ...      ...    ...  ..
# 71  0   2        110   265    1        2      130      0      0.0      0   1
#         3        112   149    0        0      125      0      1.6      1   0
# 74  0   1        120   269    0        2      121      1      0.2      0   1
# 76  0   2        140   197    0        1      116      0      1.1      1   0
# 77  1   3        125   304    0        2      162      1      0.0      0   3
#
#             thal  target
# ...

# %%
ds.sort_values('age', ascending=True)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   29    1   1       130   204    0        2      202      0      0.0
# 101   34    1   0       118   182    0        2      174      0      0.0
# 225   34    0   1       118   210    0        0      192      0      0.7
# 168   35    1   3       126   282    0        2      156      1      0.0
# 117   35    0   3       138   183    0        0      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 42    71    0   1       160   302    0        0      162      0      0.4
# 103   71    0   2       110   265    1        2      130      0      0.0
# 233   74    0   1       120   269    0        2      121      1      0.2
# 257   76    0   2       140   197    0        1      116      0      1.1
# 161   77    1   3       125   304    0        2      162      1      0.0
#
#      slope  ca  thal  target
# 132      0   0     1       0
# 101      0   0     1       0
# ...

# %%
ds_sort = ds.sort_values('age', ascending=True).iloc[0:10] 
ds_sort.plot.barh(x='sex', y='age')
# Out:
# <Axes: ylabel='sex'>
